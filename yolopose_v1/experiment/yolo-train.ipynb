# %%
import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

# %%
# Load a model
# model = YOLO("yolo11m-pose.pt")  # load an official model
model = YOLO("best_100.pt")  # load a custom model
# model = YOLO("best_100.pt")

# %%
# Predict with the model
results2 = model.predict("52723_8_4.jpg", show = True, save = True)  # predict on an image
results1 = model.predict("52701_11_9.jpg", show = True, save = True)
results = model.predict("52738_5_55.jpg", show = True, save = True)

# Access the results
for result2 in results2:
    xy = result2.keypoints.xy  # x and y coordinates
    xyn = result2.keypoints.xyn  # normalized
    kpts = result2.keypoints.data  # x, y, visibility (if available)

for result1 in results1:
    xy = result1.keypoints.xy  # x and y coordinates
    xyn = result1.keypoints.xyn  # normalized
    kpts = result1.keypoints.data  # x, y, visibility (if available)

for result in results:
    xy = result.keypoints.xy  # x and y coordinates
    xyn = result.keypoints.xyn  # normalized
    kpts = result.keypoints.data  # x, y, visibility (if available)
# Out:
# image 1/1 c:\Users\UDESIAS\Documents\FYP\Fine-Tune\yolopose_v1\experiment\52723_8_4.jpg: 640x448 1 person, 307.6ms
# Speed: 3.7ms preprocess, 307.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to c:\Users\UDESIAS\Documents\FYP\CNN-GCN-Pipeline\runs\pose\predict13
#
# image 1/1 c:\Users\UDESIAS\Documents\FYP\Fine-Tune\yolopose_v1\experiment\52701_11_9.jpg: 640x512 1 person, 364.1ms
# Speed: 4.4ms preprocess, 364.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to c:\Users\UDESIAS\Documents\FYP\CNN-GCN-Pipeline\runs\pose\predict13
#
# image 1/1 c:\Users\UDESIAS\Documents\FYP\Fine-Tune\yolopose_v1\experiment\52738_5_55.jpg: 640x416 1 person, 268.9ms
# Speed: 3.7ms preprocess, 268.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
# Results saved to c:\Users\UDESIAS\Documents\FYP\CNN-GCN-Pipeline\runs\pose\predict13

# %%
# Plot the results
# results[0].plot()

# %%
import cv2
import numpy as np

# Load the original image
image_path = result1.orig_img
# image = cv2.imread("52723_8_4.jpg")
image = cv2.imread("52701_11_9.jpg")

# Convert the image from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Draw keypoints on the image
for person in xy:
    for point in person:
        x, y = int(point[0]), int(point[1])
        if x > 0 and y > 0:  # Only draw valid points
            cv2.circle(image, (x, y), 5, (0, 255, 0), -1)

# Display the image
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
