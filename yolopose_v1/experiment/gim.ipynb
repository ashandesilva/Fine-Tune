# %%
import ultralytics
from ultralytics import YOLO

# %%
model = YOLO("yolo11m-pose.pt")

# %%
results = model.track("gim_3_8.mp4", show = True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/239) c:\Users\UDESIAS\Documents\FYP\Fine-Tune\yolopose_v1\experiment\gim_3_8.mp4: 384x640 1 person, 777.7ms
# video 1/1 (frame 2/239) c:\Users\UDESIAS\Documents\FYP\Fine-Tune\yolopose_v1\experiment\gim_3_8.mp4: 384x640 1 person, 749.9ms
# video 1/1 (frame 3/239) c:\Users\UDESIAS\Documents\FYP\Fine-Tune\yolopose_v1\experiment\gim_3_8.mp4: 384x640 1 person, 972.9ms
# ...
