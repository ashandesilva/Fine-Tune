# %%
import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

# %%
# Load a model
# model = YOLO("yolo11m-pose.pt")  # load an official model
model = YOLO("best.pt")  # load a custom model

# %%
# Predict with the model
# results = model.predict("52723_8_4.jpg", show = True, save = True)  # predict on an image
# results = model.predict("52701_11_9.jpg", show = True, save = True)
results = model.predict("52738_5_55.jpg", show = True, save = True)

# Access the results
for result in results:
    xy = result.keypoints.xy  # x and y coordinates
    xyn = result.keypoints.xyn  # normalized
    kpts = result.keypoints.data  # x, y, visibility (if available)
# Out:
# image 1/1 c:\Users\UDESIAS\Documents\FYP\Fine-Tune\yolopose_v1\experiment\52738_5_55.jpg: 640x416 1 person, 2076.3ms
# Speed: 5.1ms preprocess, 2076.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
# Results saved to c:\Users\UDESIAS\Documents\FYP\CNN-GCN-Pipeline\runs\pose\predict3

# %%
# Plot the results
# results[0].plot()

# %%
import cv2
import numpy as np

# Load the original image
image_path = result.orig_img
# image = cv2.imread("52723_8_4.jpg")
image = cv2.imread("52738_5_55.jpg")

# Convert the image from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Draw keypoints on the image
for person in xy:
    for point in person:
        x, y = int(point[0]), int(point[1])
        if x > 0 and y > 0:  # Only draw valid points
            cv2.circle(image, (x, y), 5, (0, 255, 0), -1)

# Display the image
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis('off')
plt.show()
